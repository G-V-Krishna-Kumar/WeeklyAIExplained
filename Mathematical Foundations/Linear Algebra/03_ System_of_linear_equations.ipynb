# %% [markdown]
# # System of Linear Equations
#
# #### Given a system of m equations and n unknowns, there are 3 cases.
#
# ## Case 1: When m=n
# #### There are n unknowns and there are n equations. So, there are 2 possible scenarios. It can either have a unique solution or can have no solution at all. We can visualize this by thinking of the input and output spaces.
