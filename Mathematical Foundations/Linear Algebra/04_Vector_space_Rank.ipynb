# %% [markdown]
# # Span
# #### Span is all the possible linear combinations of the given set of vectors. For example, span{[1 0], [0 1]}, we can visualize it by thinking of all the possible linear combinations of these vectors. The possible vectors or the points we can reach is all the points in the $R^2$ space.
#
# # Vector Space
# #### It is the output space of
